# %% [markdown]
# # ACTIVIDAD 1:
#
# - ** Fuente de datos **: [DATOS FUENTE](https://www.datos.gov.co/Transporte/Accidentes-de-Transito-ocurridos-en-el-Municipio-d/7cci-nqqb/about_data)
# - Intro: Elegí este dataset debido a su relevancia en terminos de seguridad vial y gestión del tráfico urbano, los cuales pueden ser utilizados para realizar análisis, tendencias a lo largo del tiempo, lo que ayuda en la identificación de patrones y puntos críticos.
# - Objetivo Principal:

# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
path = os.getcwd()
print(os.listdir())
filename=[x for x in os.listdir() if 'Bucaramanga' in x] [0]
filename
# Out:
# ['Accidentes_de_Transito_ocurridos_en_el_Municipio_de_Bucaramanga_20240729.csv', 'Act1.ipynb']
# 'Accidentes_de_Transito_ocurridos_en_el_Municipio_de_Bucaramanga_20240729.csv'

# %%
path+ '//' +filename
# Out:
# 'c:\\Users\\Admin\\BOOTCAMP-DS-2024-I\\DataScience BITcoin//Accidentes_de_Transito_ocurridos_en_el_Municipio_de_Bucaramanga_20240729.csv'

# %%
ab=pd.read_csv(path+ '//' +filename,sep=',', encoding='utf-8')
ab
# Out:
#        ORDEN       FECHA   AÑO             MES            DÍA     GRAVEDAD  \
# 0          1  01/01/2012  2012       01. Enero    07. Domingo  Con heridos
# 1          2  01/01/2012  2012       01. Enero    07. Domingo   Solo daños
# 2          3  01/01/2012  2012       01. Enero    07. Domingo   Solo daños
# 3          4  01/01/2012  2012       01. Enero    07. Domingo   Solo daños
# 4          5  01/01/2012  2012       01. Enero    07. Domingo  Con heridos
# ...      ...         ...   ...             ...            ...          ...
# 39188  39189  12/04/2023  2023       04. Abril  03. Miercoles  Con Muertos
# 39189  39190  22/09/2023  2023  09. Septiembre    05. Viernes  Con Muertos
# 39190  39191  23/09/2023  2023  09. Septiembre     06. Sabado  Con Muertos
# 39191  39192  24/09/2023  2023  09. Septiembre    07. Domingo  Con Muertos
# 39192  39193  26/09/2023  2023  09. Septiembre     02. Martes  Con Muertos
#
#        PEATON  AUTOMOVIL  CAMPERO  CAMIONETA  ...  VOLQUETA  MOTO  BICICLETA  \
# 0           0          1        0          0  ...         0     0          0
# 1           0          1        0          1  ...         0     0          0
# 2           0          0        0          1  ...         0     0          0
# 3           0          1        0          1  ...         0     0          0
# 4           1          0        0          0  ...         0     1          0
# ...       ...        ...      ...        ...  ...       ...   ...        ...
# 39188       0          1        0          0  ...         0     1          0
# 39189       0          0        0          0  ...         0     1          0
# 39190       0          0        0          0  ...         0     1          0
# 39191       0          1        0          0  ...         0     1          0
# 39192       0          0        0          0  ...         0     0          0
#
#        OTRO              BARRIO      HORA      ENTIDAD  \
# 0         0               Mutis  12:15:00  AGENTES DTB
# 1         0     Regaderos Norte  14:00:00  AGENTES DTB
# 2         0  Cabecera Del Llano  12:00:00  AGENTES DTB
# 3         0          Norte Bajo  18:30:00  AGENTES DTB
# 4         0             Dangond  00:30:00  AGENTES DTB
# ...     ...                 ...       ...          ...
# 39188     0        La Concordia  21:00:00  AGENTES DTB
# 39189     0           Colorados  09:30:00  AGENTES DTB
# 39190     0           Morrorico  01:00:00  AGENTES DTB
# 39191     0       NO DISPONIBLE  02:15:00  AGENTES DTB
# 39192     0           Colorados  10:40:00  AGENTES DTB
#
#                        COMUNA Propietario de Vehículo DIURNIO/NOCTURNO
# 0                   17. MUTIS              Particular           Diurno
# 1             02. NORORIENTAL                 Empresa           Diurno
# 2      12. CABECERA DEL LLANO              Particular           Diurno
# 3           03. SAN FRANCISCO                 Empresa         Nocturno
# 4                     11. SUR              Particular         Nocturno
# ...                       ...                     ...              ...
# 39188        06. LA CONCORDIA                 Empresa         Nocturno
# 39189               01. NORTE              Particular           Diurno
# 39190           14. MORRORICO              Particular         Nocturno
# 39191           NO DISPONIBLE              Particular         Nocturno
# 39192               01. NORTE                 Empresa           Diurno
#
# [39193 rows x 24 columns]

# %%
print(ab.shape)
print(ab["GRAVEDAD"].value_counts())
print(ab["GRAVEDAD"].value_counts().head(2))
ab.columns
# Out:
# (39193, 24)
# GRAVEDAD
# Solo daños     19602
# Con heridos    18982
# Con muertos      503
# Con Muertos      106
# Name: count, dtype: int64
# GRAVEDAD
# Solo daños     19602
# Con heridos    18982
# Name: count, dtype: int64
# Index(['ORDEN', 'FECHA', 'AÑO', 'MES', 'DÍA', 'GRAVEDAD', 'PEATON',
#        'AUTOMOVIL', 'CAMPERO', 'CAMIONETA', 'MICRO', 'BUSETA', 'BUS', 'CAMION',
#        'VOLQUETA', 'MOTO', 'BICICLETA', 'OTRO', 'BARRIO', 'HORA', 'ENTIDAD',
#        'COMUNA', 'Propietario de Vehículo', 'DIURNIO/NOCTURNO'],
#       dtype='object')

# %%
##ab["ENTIDAD"].unique()
##ab["BARRIO"].unique()
##ab["GRAVEDAD"].unique()
ab["GRAVEDAD"].unique()
# Out:
# array(['Mutis', 'Regaderos Norte', 'Cabecera Del Llano', 'Norte Bajo',
#        'Dangond', 'San Miguel', 'La Pedregosa', 'Bucaramanga',
#        'Tejar Norte', 'Sotomayor', 'Fontana', 'Provenza',
#        'Nuevo Sotomayor', 'Cafe Madrid', 'Centro', 'Alvarez', 'Asturias',
#        'Bolarqui', 'Los Pinos', 'Manuela Beltran', 'NO DISPONIBLE',
#        'Alarcon', 'Real De Minas', 'Antonia Santos Centro', 'Conucos',
#        'La Aurora', 'Mejoras Publicas', 'Girardot', 'San Alonso',
#        'Juan Xxiii', 'La Ceiba', 'Comuneros', 'Antonia Santos Sur',
#        'La Concordia', 'Asopofavi', 'La Victoria', 'San Francisco',
#        'Lagos del Cacique', 'El Jardin', 'Colseguros Norte', 'Colorados',
#        'Miraflores', 'Villa Alicia', 'Garcia Rovira', 'Candiles',
#        'Bolivar', 'El Tejar', 'Jardines De Coaviconsa', 'Campo Hermoso',
#        'Esperanza I', 'Universidad', 'San Rafael', 'Ricaurte', 'Kennedy',
#        'Rio de Oro I', '10 de mayo Santa Barbara', 'Estoraques',
#        'Quinta Estrella', 'San Gerardo', 'Diamante I', 'Alfonso Lopez',
#        'Diamante Ii', 'Puerta del Sol', 'Africa', 'Chapinero',
#        'Morrorico', 'El Rocio', 'Modelo', 'Diamante II', 'Gaitan',
#        'Antiguo Campestre', 'Canelos', 'El Prado', 'Terrazas',
#        'Chorreras De Don Juan', 'Toledo Plata', 'Robles',
#        'Delicias Altas', 'El Porvenir', 'Manzanares', 'Albania',
#        'Mercedes', 'La Joya', 'La Floresta', 'Pan De Azucar', 'Betania',
#        'Villa Mercedes', 'Bosque norte', 'La Feria', 'Ciudad Venecia',
#        'La Salle', 'Mutualidad', 'Villa Helena', 'Nariño', 'La Libertad',
#        'La Juventud', 'Olas Ii', 'Nueva Granada', 'Santander',
#        'San Martin', 'Monterredondo', 'Vijagual', 'Quinta Brigada',
#        'Villa Diamante', 'San Expedito', 'Pedregal', 'Villa Rosa',
#        'Puerta Del Sol', '13 De Junio', 'La Independencia',
#        'Los Guayacanes', 'Granada', 'Delicias', 'Quebrada La Iglesia I',
#        'Brisas Del Mutis', 'Cabecera del Llano', 'Quintadania',
#        'Quebrada La Iglesia', 'La Esmeralda', 'Malpaso', 'Buenos Aires',
#        'Omaga Ii', 'Lagos Del Cacique', 'Sauces', 'Vegas De Morrorico',
#        'Retiro Grande Acueducto', 'Limoncito', 'Prados Del Mutis',
#        'Altos del Progreso', 'Altos Del Lago', 'Maria Paz', 'San Luis',
#        'El Plan', '10 De Mayo Santa Barbara', 'Balconcitos', 'Napoles',
#        'Claveriano', 'Villa Maria I', 'El Diviso', 'Bosconia',
#        'Los Heroes', 'Hacienda San Juan', 'Transicion I-V',
#        'Cristal Alto', 'Villas de San Ignacio', 'Los Angeles',
#        'San Cristobal', 'Miramar', 'Altos del Cacique', 'Pablo Vi',
#        'Esperanza Ii', 'Santa Maria', 'Villa Ines', 'Rio De Oro Ii',
#        'Villa Helena II', 'Minuto De Dios', 'Esperanza Iii', 'Los Cedros',
#        'Villa Sara', 'Las Hamacas', 'San Pedro Claver', 'Pan de Azucar',
#        'Balcones Del Kennedy', 'Gomez Niño', '23 De Junio', 'Olas Bajas',
#        'Venado De Oro', 'Buenavista', 'Don Bosco', 'Omaga I', 'Galan',
#        '12 De Octubre', 'Puerto Rico', 'Porto Fino', 'Candado',
#        'Altos Del Kennedy', 'Granjas De Provenza', 'Altos del Jardin',
#        'Pio XII', '20 De Julio', 'Miradores Del Kennedy', 'El Pablon',
#        'Quebrada la Iglesia II', 'ROSABLANCA', 'Real de Minas',
#        'Cristal Bajo'], dtype=object)

# %%
Lugar= input("Ingresa_barrio")
lista=set(ab["BARRIO"].unique())
try:
    lista_filtro=[x for x in lista if Lugar in x]
    if len(lista_filtro)>0:
        print(lista_filtro)
    else:
            print("no encontrado")
except:
         print("error")
# Out:
# no encontrado
